# %%
import pandas as pd

# %%
excel_file = '/content/single quarter data.xlsx'
df = pd.read_excel(excel_file)

csv_file = 'data.csv'

df.to_csv(csv_file, index=False)

# %%
data = pd.read_csv("/content/data.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#   Sample Data - Since August 2021     Unnamed: 1      Unnamed: 2  Unnamed: 3  \
# 0                       Bulk Data            NaN             NaN         NaN
# 1                           Month  Sample Serial  Accredited Lab       State
# 2                             NaN            NaN             NaN         NaN
# 3             2024-05-08 00:00:00              1               1  TAMIL NADU
# 4             2024-05-09 00:00:00              2               2  TAMIL NADU
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7   Unnamed: 8  \
# 0         NaN        NaN        NaN        NaN          NaN
# 1    District      Taluk      Block    Village  SAMPLE CODE
# 2         NaN        NaN        NaN        NaN          NaN
# 3  Coimbatore      Sulur        NaN        NaN   TNCOE24001
# 4  Coimbatore      Sulur        NaN        NaN   TNCOE24002
#
#                    Unnamed: 9  ...      Unnamed: 29 Unnamed: 30 Unnamed: 31  \
# 0                         NaN  ...              NaN         NaN         NaN
# 1  Sample \nCollection\n Date  ...  Burette reading         NaN  Difference
# 2                         NaN  ...          Initial       Final         NaN
# 3         2024-05-13 00:00:00  ...                0         0.1         0.1
# 4         2024-05-13 00:00:00  ...                0           0           0
#
#          Unnamed: 32      Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 0                NaN              NaN         NaN         NaN
# 1  Result 1 (in ppm)  Burette reading         NaN  Difference
# 2                NaN          Initial       Final         NaN
# 3              1.058                0         0.1         0.1
# 4                  0                0           0           0
#
#          Unnamed: 36  Unnamed: 37 Unnamed: 38
# 0                NaN          NaN         NaN
# 1  Result 2 (in ppm)  Average ppm     Remarks
# 2                NaN          NaN         NaN
# 3              1.058        1.058         NaN
# 4                  0            0         NaN
#
# [5 rows x 39 columns]

# %%
df = df[["Unnamed: 4", "Unnamed: 13", "Unnamed: 14", "Unnamed: 15", "Unnamed: 37"]]
df.head()
# Out:
#    Unnamed: 4                                        Unnamed: 13 Unnamed: 14  \
# 0         NaN                                                NaN         NaN
# 1    District  Salt Producer Name / Address / Contact Informa...  Brand Name
# 2         NaN                                                NaN         NaN
# 3  Coimbatore  SSP Salt, 5/54, North Street, Thulukkankulam, ...         AMS
# 4  Coimbatore  MPS Salt Tradesrs, 63, Victoria Street, Thootr...         MPS
#
#                              Unnamed: 15  Unnamed: 37
# 0                                    NaN          NaN
# 1  Type of salt Crystal/ Powder/  Refind  Average ppm
# 2                                    NaN          NaN
# 3                                Crystal        1.058
# 4                                Crystal            0

# %%
df.columns = ["District", "Producer", "Brand", "Salt Type", "Average ppm"]
df.head()
# Out:
#      District                                           Producer       Brand  \
# 0         NaN                                                NaN         NaN
# 1    District  Salt Producer Name / Address / Contact Informa...  Brand Name
# 2         NaN                                                NaN         NaN
# 3  Coimbatore  SSP Salt, 5/54, North Street, Thulukkankulam, ...         AMS
# 4  Coimbatore  MPS Salt Tradesrs, 63, Victoria Street, Thootr...         MPS
#
#                                Salt Type  Average ppm
# 0                                    NaN          NaN
# 1  Type of salt Crystal/ Powder/  Refind  Average ppm
# 2                                    NaN          NaN
# 3                                Crystal        1.058
# 4                                Crystal            0

# %%
df["District"] = df["District"].fillna("Unknown")
df["Producer"] = df["Producer"].fillna("Unknown")
df["Brand"] = df["Brand"].fillna("Unknown")
df["Salt Type"] = df["Salt Type"].fillna("Unknown")
df["Average ppm"] = df["Average ppm"].fillna("0")

# %%
df = df.iloc[3:]
df.head(10)
# Out:
#       District                                           Producer  \
# 3   Coimbatore  SSP Salt, 5/54, North Street, Thulukkankulam, ...
# 4   Coimbatore  MPS Salt Tradesrs, 63, Victoria Street, Thootr...
# 5   Coimbatore  Baby Salt, Sambai, Ramanathapuram-623531 Cell:...
# 6   Coimbatore  Basuvi Salt Company, 30/4, Nandagopalapuram We...
# 7   Coimbatore  Vijayavelan Traders, 332, Sundaravelpuram, Tut...
# 8   Coimbatore  Sree Meenakshi Salt Works (P) Ltd., Platform N...
# 9   Coimbatore  Sri Cherman Salt, Kurukkusalai Main Road, Opp....
# 10  Coimbatore  Shanmugar Saltens (P) Ltd., At S.N.465/1, Vepp...
# 11  Coimbatore  Basuvi Salt Company, 30/4, Nandagopalapuram We...
# 12  Coimbatore  Escee Industries Private Limited, 2/234, Melma...
#
#           Brand Salt Type         Average ppm
# 3           AMS   Crystal               1.058
# 4           MPS   Crystal                   0
# 5          Baby   Crystal  1.5870000000000002
# 6           BSC   Crystal  1.5870000000000002
# 7   Vijayavelan   Crystal                   0
# 8          Tata   Crystal              25.921
# 9    White Dove   Crystal                   0
# 10        Subam    Refine              19.573
# 11      Garudan   Crystal  12.167000000000002
# 12      Kristal   Crystal              18.515

# %%
df["Average ppm"] = df["Average ppm"].astype(float)
df["Average ppm"] = df["Average ppm"].round(1)
# Out:
# <ipython-input-8-c7c616e47268>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Average ppm"] = df["Average ppm"].astype(float)
# <ipython-input-8-c7c616e47268>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Average ppm"] = df["Average ppm"].round(1)

# %%
import numpy as np

def get_top_best_producers(df, min_ppm, max_ppm):
    filtered_df = df[(df["Average ppm"] >= min_ppm) & (df["Average ppm"] <= max_ppm)]
    median_ppm = filtered_df["Average ppm"].median()
    filtered_df["Distance to Median"] = np.abs(filtered_df["Average ppm"] - median_ppm)
    top_producers = filtered_df.sort_values(by="Distance to Median").head(10)
    return top_producers

# Get top 10 best producers (15-30 ppm)
top_best_producers = get_top_best_producers(df, 15, 30)

# Get top 10 worst producers (<15 ppm) excluding zero values
top_worst_producers = df[(df["Average ppm"] < 15) & (df["Average ppm"] > 0)].sort_values(by="Average ppm", ascending=True).head(10)

# Get top 10 over performing producers (>30 ppm)
top_overperforming_producers = df[df["Average ppm"] > 30].sort_values(by="Average ppm", ascending=False).head(10)

print("Top 10 Best Producers (15-30 ppm):")
print(top_best_producers)

print("\nTop 10 Worst Producers (<15 ppm):")
print(top_worst_producers)

print("\nTop 10 Overperforming Producers (>30 ppm):")
print(top_overperforming_producers)
# Out:
# Top 10 Best Producers (15-30 ppm):
#          District                                           Producer  \
# 264      Ariyalur  Swamy Traders & Enterprises Pvt. Ltd, 653/1, T...
# 287  Nagapattinam  VKS Foods Pvt. Ltd. 2/65-1, 2/65-2, ECR Road, ...
# 472        Trichy  VKS Foods Pvt. Ltd. 2/65-1, 2/65-2, ECR Road, ...
# 378      Tiruppur  VKS Foods Pvt. Ltd. 2/65-1, 2/65-2, ECR Road, ...
# 184    Thiruvarur  Shivayah Salt Private Limited, 5/311-2, Palaya...
# 265      Ariyalur  Sri Chairman Salt, 1/1-16, Mapillaiurani Post,...
# 605       Vellore  Escee Industries Private Limited, 2/234, Melma...
# 718     Tuticorin  Sri Alagar Salt, 4/298, Tiruchendur Road, Mull...
# 291  Nagapattinam  VKS Foods Pvt. Ltd. 2/65-1, 2/65-2, ECR Road, ...
# 523    Pudukottai  Sree Meenakshi Salt Works (P) Ltd., Platform N...
#
#         Brand Salt Type  Average ppm  Distance to Median
# 264   Piriyam    Refine         21.2                0.25
# 287      Real   Crystal         21.7                0.25
# 472   O Fresh    Refine         21.7                0.25
# 378   O Fresh   Crystal         21.2                0.25
# 184  Kayathri    Refine         21.7                0.25
# 265  Saravana    Refine         21.2                0.25
# 605   Kristal   Crystal         21.7                0.25
# 718   Piriyam   Crystal         21.2                0.25
# 291   Adithya   Crystal         21.7                0.25
# 523      Tata   Crystal         21.7                0.25
#
# Top 10 Worst Producers (<15 ppm):
#         District                                           Producer  \
# 3     Coimbatore  SSP Salt, 5/54, North Street, Thulukkankulam, ...
# 253   Villupuram  P.Karthickraja, 107/1-A, 1st Street, Krishnara...
# 254   Villupuram  P.Karthickraja, 107/1-A, 1st Street, Krishnara...
# 255   Villupuram  P.Karthickraja, 107/1-A, 1st Street, Krishnara...
# 256   Villupuram  P.Karthickraja, 107/1-A, 1st Street, Krishnara...
# 433  Krishnagiri  Akash, 5B/478, SNR Nagar, Chidambara Nagar, Th...
# 435  Krishnagiri  Akash, 5B/478, SNR Nagar, Chidambara Nagar, Th...
# 437  Krishnagiri  Akash, 5B/478, SNR Nagar, Chidambara Nagar, Th...
# 97    Dharmapuri  Andavar Salt, 138, G.C.Road, Tuticorin-628001 ...
# 94    Dharmapuri  Andavar Salt, 138, G.C.Road, Tuticorin-628001 ...
#
#          Brand Salt Type  Average ppm
# 3          AMS   Crystal          1.1
# 253  Raja Gold   Crystal          1.1
# 254  Raja Gold   Crystal          1.1
# 255  Raja Gold   Crystal          1.1
# 256  Raja Gold   Crystal          1.1
# 433         JJ   Crystal          1.1
# 435         JJ   Crystal          1.1
# 437         JJ   Crystal          1.1
# 97        Sony   Crystal          1.1
# 94        Sony   Crystal          1.1
#
# Top 10 Overperforming Producers (>30 ppm):
#            District                                           Producer  \
# 126        Dindugul  Ganesh Powder Salt Company, 193/41, Old Market...
# 660      Perambalur  Jayalakshmi & Co, 225/1, Ayyanarpuram post, Ke...
# 125        Dindugul  Ganesh Powder Salt Company, 193/41, Old Market...
# 271        Ariyalur  Swamy Traders & Enterprises Pvt. Ltd, 653/1, T...
# 149  Ramanadhapuram  Sahayamatha Salterns P Ltd, At Survey No.1&2/3...
# 661      Perambalur  Jayalakshmi & Co, 225/1, Ayyanarpuram post, Ke...
# 269        Ariyalur  Swamy Traders & Enterprises Pvt. Ltd, 653/1, T...
# 189      Thiruvarur  Swamy Traders & Enterprises Pvt. Ltd, 653/1, T...
# 162  Ramanadhapuram  Escee Industries Private Limited, 2/234, Melma...
# 238    Kallakurichi  Swamy Traders & Enterprises Pvt. Ltd, 653/1, T...
#
#         Brand Salt Type  Average ppm
# 126       NCS   Crystal        212.1
# 660     Jeyel   Crystal        116.9
# 125  Kasthuri   Crystal         65.6
# 271   Piriyam    Refine         64.5
# 149  Sprinkle    Refine         64.5
# 661     Jeyel   Crystal         64.0
# 269   Piriyam    Refine         62.4
# 189      Tata   Crystal         56.1
# 162   Piriyam   Crystal         47.6
# 238   Piriyam    Refine         47.1
# <ipython-input-9-e0425bf21027>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Distance to Median"] = np.abs(filtered_df["Average ppm"] - median_ppm)

# %%
# !pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (0.9.0)

# %%
from tabulate import tabulate

# Define a function to print DataFrames as tables
def print_table(df, title):
    print(f"\n{title}")
    print(tabulate(df, headers='keys', tablefmt='grid'))

# Print the tables
print_table(top_best_producers, "Top 10 Best Producers (15-30 ppm)")
print_table(top_worst_producers, "Top 10 Worst Producers (<15 ppm)")
print_table(top_overperforming_producers, "Top 10 Overperforming Producers (>30 ppm)")
# Out:
# Top 10 Best Producers (15-30 ppm)
# +-----+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+----------------------+
# |     | District     | Producer                                                                                                                                                                | Brand    | Salt Type   |   Average ppm |   Distance to Median |
# +=====+==============+=========================================================================================================================================================================+==========+=============+===============+======================+
# | 264 | Ariyalur     | Swamy Traders & Enterprises Pvt. Ltd, 653/1, Tiruchendur Road, Mullakadu, Tuticorin - 628005                                                                            | Piriyam  | Refine      |          21.2 |                 0.25 |
# +-----+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+----------------------+
# | 287 | Nagapattinam | VKS Foods Pvt. Ltd. 2/65-1, 2/65-2, ECR Road, Keela Arasaradi, Ottapidaram Taluk, Tuticorin-628002. TamilNadu Cell: 9788855021, 978885518 Email:factorysalt@vksfoods.in | Real     | Crystal     |          21.7 |                 0.25 |
# +-----+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+----------------------+
# | 472 | Trichy       | VKS Foods Pvt. Ltd. 2/65-1, 2/65-2, ECR Road, Keela Arasaradi, Ottapidaram Taluk, Tuticorin-628002. TamilNadu Cell: 9788855021, 978885518 Email:factorysalt@vksfoods.in | O Fresh  | Refine      |          21.7 |                 0.25 |
# +-----+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+----------------------+
# | 378 | Tiruppur     | VKS Foods Pvt. Ltd. 2/65-1, 2/65-2, ECR Road, Keela Arasaradi, Ottapidaram Taluk, Tuticorin-628002. TamilNadu Cell: 9788855021, 978885518 Email:factorysalt@vksfoods.in | O Fresh  | Crystal     |          21.2 |                 0.25 |
# +-----+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+----------------------+
# | 184 | Thiruvarur   | Shivayah Salt Private Limited, 5/311-2, Palayakayal, District - Thoothukudi, Srivaikundam Block, Thoothukudi-628152                                                     | Kayathri | Refine      |          21.7 |                 0.25 |
# +-----+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+----------------------+
# | 265 | Ariyalur     | Sri Chairman Salt, 1/1-16, Mapillaiurani Post, Tuticorin - 628002 Cell: 9442228377 Email: chairman@saravanasalt.com                                                     | Saravana | Refine      |          21.2 |                 0.25 |
# +-----+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+----------------------+
# | 605 | Vellore      | Escee Industries Private Limited, 2/234, Melmanthai Village, Vilathikulam Taluk, Tuticorin District-628901 Cell: 7009001920 Ph:04445520167                              | Kristal  | Crystal     |          21.7 |                 0.25 |
# +-----+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+----------------------+
# | 718 | Tuticorin    | Sri Alagar Salt, 4/298, Tiruchendur Road, Mullakadu, Tuticorin - 628005                                                                                                 | Piriyam  | Crystal     |          21.2 |                 0.25 |
# +-----+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+----------------------+
# | 291 | Nagapattinam | VKS Foods Pvt. Ltd. 2/65-1, 2/65-2, ECR Road, Keela Arasaradi, Ottapidaram Taluk, Tuticorin-628002. TamilNadu Cell: 9788855021, 978885518 Email:factorysalt@vksfoods.in | Adithya  | Crystal     |          21.7 |                 0.25 |
# +-----+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+----------------------+
# | 523 | Pudukottai   | Sree Meenakshi Salt Works (P) Ltd., Platform No. II, Urani Salt Factory, Urani, District - Thoothukudi TamilNadu - 628006                                               | Tata     | Crystal     |          21.7 |                 0.25 |
# +-----+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+----------------------+
#
# Top 10 Worst Producers (<15 ppm)
# +-----+-------------+-----------------------------------------------------------------------------------------------------------+-----------+-------------+---------------+
# |     | District    | Producer                                                                                                  | Brand     | Salt Type   |   Average ppm |
# +=====+=============+===========================================================================================================+===========+=============+===============+
# |   3 | Coimbatore  | SSP Salt, 5/54, North Street, Thulukkankulam, Vaippar, Tuticorin Dist.,- 628903 Ph: 9597501980, 950080404 | AMS       | Crystal     |           1.1 |
# +-----+-------------+-----------------------------------------------------------------------------------------------------------+-----------+-------------+---------------+
# | 253 | Villupuram  | P.Karthickraja, 107/1-A, 1st Street, Krishnarajapuram, Tuticorin. Customer Care: 9443126831               | Raja Gold | Crystal     |           1.1 |
# +-----+-------------+-----------------------------------------------------------------------------------------------------------+-----------+-------------+---------------+
# | 254 | Villupuram  | P.Karthickraja, 107/1-A, 1st Street, Krishnarajapuram, Tuticorin. Customer Care: 9443126831               | Raja Gold | Crystal     |           1.1 |
# +-----+-------------+-----------------------------------------------------------------------------------------------------------+-----------+-------------+---------------+
# | 255 | Villupuram  | P.Karthickraja, 107/1-A, 1st Street, Krishnarajapuram, Tuticorin. Customer Care: 9443126831               | Raja Gold | Crystal     |           1.1 |
# +-----+-------------+-----------------------------------------------------------------------------------------------------------+-----------+-------------+---------------+
# | 256 | Villupuram  | P.Karthickraja, 107/1-A, 1st Street, Krishnarajapuram, Tuticorin. Customer Care: 9443126831               | Raja Gold | Crystal     |           1.1 |
# +-----+-------------+-----------------------------------------------------------------------------------------------------------+-----------+-------------+---------------+
# | 433 | Krishnagiri | Akash, 5B/478, SNR Nagar, Chidambara Nagar, Thoothukudi. Cell: 7708460429                                 | JJ        | Crystal     |           1.1 |
# +-----+-------------+-----------------------------------------------------------------------------------------------------------+-----------+-------------+---------------+
# | 435 | Krishnagiri | Akash, 5B/478, SNR Nagar, Chidambara Nagar, Thoothukudi. Cell: 7708460429                                 | JJ        | Crystal     |           1.1 |
# +-----+-------------+-----------------------------------------------------------------------------------------------------------+-----------+-------------+---------------+
# | 437 | Krishnagiri | Akash, 5B/478, SNR Nagar, Chidambara Nagar, Thoothukudi. Cell: 7708460429                                 | JJ        | Crystal     |           1.1 |
# +-----+-------------+-----------------------------------------------------------------------------------------------------------+-----------+-------------+---------------+
# |  97 | Dharmapuri  | Andavar Salt, 138, G.C.Road, Tuticorin-628001 Cell: 9842172821                                            | Sony      | Crystal     |           1.1 |
# +-----+-------------+-----------------------------------------------------------------------------------------------------------+-----------+-------------+---------------+
# |  94 | Dharmapuri  | Andavar Salt, 138, G.C.Road, Tuticorin-628001 Cell: 9842172821                                            | Sony      | Crystal     |           1.1 |
# +-----+-------------+-----------------------------------------------------------------------------------------------------------+-----------+-------------+---------------+
#
# Top 10 Overperforming Producers (>30 ppm)
# +-----+----------------+--------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+
# |     | District       | Producer                                                                                                                                   | Brand    | Salt Type   |   Average ppm |
# +=====+================+============================================================================================================================================+==========+=============+===============+
# | 126 | Dindugul       | Ganesh Powder Salt Company, 193/41, Old Market, Thoothukudi-628001 Phone: 0461-2326449, 2322697                                            | NCS      | Crystal     |         212.1 |
# +-----+----------------+--------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+
# | 660 | Perambalur     | Jayalakshmi & Co, 225/1, Ayyanarpuram post, Keela Arasaladi Village, Ottapidaram Taluk, Tuticorin-628002                                   | Jeyel    | Crystal     |         116.9 |
# +-----+----------------+--------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+
# | 125 | Dindugul       | Ganesh Powder Salt Company, 193/41, Old Market, Thoothukudi-628001 Phone: 0461-2326449, 2322697                                            | Kasthuri | Crystal     |          65.6 |
# +-----+----------------+--------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+
# | 271 | Ariyalur       | Swamy Traders & Enterprises Pvt. Ltd, 653/1, Tiruchendur Road, Mullakadu, Tuticorin - 628005                                               | Piriyam  | Refine      |          64.5 |
# +-----+----------------+--------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+
# | 149 | Ramanadhapuram | Sahayamatha Salterns P Ltd, At Survey No.1&2/3, Pattanamarudur Village, Ottapidaram Taluk, Tuticorin Dist., TamilNadu-628903               | Sprinkle | Refine      |          64.5 |
# +-----+----------------+--------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+
# | 661 | Perambalur     | Jayalakshmi & Co, 225/1, Ayyanarpuram post, Keela Arasaladi Village, Ottapidaram Taluk, Tuticorin-628002                                   | Jeyel    | Crystal     |          64   |
# +-----+----------------+--------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+
# | 269 | Ariyalur       | Swamy Traders & Enterprises Pvt. Ltd, 653/1, Tiruchendur Road, Mullakadu, Tuticorin - 628005                                               | Piriyam  | Refine      |          62.4 |
# +-----+----------------+--------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+
# | 189 | Thiruvarur     | Swamy Traders & Enterprises Pvt. Ltd, 653/1, Tiruchendur Road, Mullakadu, Tuticorin - 628005                                               | Tata     | Crystal     |          56.1 |
# +-----+----------------+--------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+
# | 162 | Ramanadhapuram | Escee Industries Private Limited, 2/234, Melmanthai Village, Vilathikulam Taluk, Tuticorin District-628901 Cell: 7009001920 Ph:04445520167 | Piriyam  | Crystal     |          47.6 |
# +-----+----------------+--------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+
# | 238 | Kallakurichi   | Swamy Traders & Enterprises Pvt. Ltd, 653/1, Tiruchendur Road, Mullakadu, Tuticorin - 628005                                               | Piriyam  | Refine      |          47.1 |
# +-----+----------------+--------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+---------------+

# %%
top_best_producers.to_excel('top_best_producers.xlsx', index=False)
top_worst_producers.to_excel('top_worst_producers.xlsx', index=False)
top_overperforming_producers.to_excel('top_overperforming_producers.xlsx', index=False)

# %%
with pd.ExcelWriter('salt_producer_analysis.xlsx') as writer:
    top_best_producers.to_excel(writer, sheet_name='Top 10 Best Producers (15-30 ppm)', index=False)
    top_worst_producers.to_excel(writer, sheet_name='Top 10 Worst Producers (<15 ppm)', index=False)
    top_overperforming_producers.to_excel(writer, sheet_name='Top 10 Overperforming Producers (>30 ppm)', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/workbook/child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Create a histogram of average ppm
plt.figure(figsize=(6, 6))
sns.histplot(df['Average ppm'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Average ppm')
plt.xlabel('Average ppm')
plt.ylabel('ppm value')
plt.show()

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
average_ppm_by_producer = df.groupby("Salt Type")["Average ppm"].mean().sort_values(ascending=False)
average_ppm_by_producer.plot(kind='bar', color='skyblue')
plt.title('Average ppm by Producer')
plt.xlabel('Salt Type')
plt.ylabel('Average ppm')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['Average ppm'].plot(kind='hist', bins=20, color='green', edgecolor='black')
plt.title('Distribution of Average ppm')
plt.xlabel('Average ppm')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# 1. Pie Chart for Distribution of Salt Types
salt_type_counts = df['Salt Type'].value_counts()
plt.figure(figsize=(10, 6))
salt_type_counts.plot(kind='pie', autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=140, wedgeprops=dict(edgecolor='w'))
plt.title('Distribution of Salt Types')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
# 3. Pie Chart for Distribution of Districts
district_counts = df['District'].value_counts().head(10)  # Top 10 districts for clarity
plt.figure(figsize=(10, 6))
district_counts.plot(kind='pie', autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=140, wedgeprops=dict(edgecolor='w'))
plt.title('Distribution of Top 10 Districts')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
# 2. Pie Chart for Distribution of Producers
producer_counts = df['Brand'].value_counts().head(10)  # Top 10 producers for clarity
plt.figure(figsize=(10, 6))
producer_counts.plot(kind='pie', autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=140, wedgeprops=dict(edgecolor='w'))
plt.title('Distribution of Top 10 Producers')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
# Scatter Plot for Average ppm vs. District
plt.figure(figsize=(12, 6))
plt.scatter(x='District', y='Average ppm', data=df)
plt.title('Average ppm vs. District')
plt.xlabel('District')
plt.ylabel('Average ppm')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Box Plot for Average ppm by District (Top 10 Districts for clarity)
top_districts = df['District'].value_counts().index[:10]
df_top_districts = df[df['District'].isin(top_districts)]

plt.figure(figsize=(14, 8))
sns.boxplot(x='District', y='Average ppm', data=df_top_districts)
plt.title('Average ppm by Top 10 Districts')
plt.xlabel('District')
plt.ylabel('Average ppm')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
top_districts = df['District'].value_counts().index[:10]
df_top_districts = df[df['District'].isin(top_districts)]

plt.figure(figsize=(14, 8))
avg_ppm_by_district = df_top_districts.groupby('District')['Average ppm'].mean().sort_values()
avg_ppm_by_district.plot(kind='bar', color='red')
plt.title('Average ppm by Top 10 Districts')
plt.xlabel('District')
plt.ylabel('Average ppm')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 5. Total count of unique producers
total_unique_producers = df['Producer'].nunique()
print(f"Total count of unique producers: {total_unique_producers}")
# Out:
# Total count of unique producers: 101

# %%
producer_performance = df.groupby('Producer')['Average ppm'].agg(
    less_than_15=lambda x: (x < 15).sum(),
    between_15_30=lambda x: ((x >= 15) & (x <= 30)).sum(),
    greater_than_30=lambda x: (x > 30).sum()
).reset_index()

# Calculate total number of samples for each producer
producer_performance['Total_samples'] = producer_performance[['less_than_15', 'between_15_30', 'greater_than_30']].sum(axis=1)

# Calculate the percentage of samples with average ppm between 15-30
producer_performance['Percentage_15_30'] = (producer_performance['between_15_30'] / producer_performance['Total_samples']) * 100

# Reorder columns
producer_performance = producer_performance[['Producer', 'Total_samples', 'less_than_15', 'between_15_30', 'greater_than_30', 'Percentage_15_30']]

# Save results to an Excel file
producer_performance.to_excel('producer_performance.xlsx', index=False)

# Display the results
print(producer_performance)
# Out:
#                                               Producer  Total_samples  \
# 0    A.S.R.Company, 5A/95, Caldwell Colony Main Roa...              1
# 1    A.S.R.Traders, 4/44C, Caldwell Colony, 2nd Str...              6
# 2        AK Salt, Thiruchendur Main Road, Thoothukudi.              6
# 3    AR Salt Company, 2/164-1, Paripoorana Nagar, P...             16
# 4    Adisil Natual Foods, #2, 7/18, Theruveethi Amm...              1
# ..                                                 ...            ...
# 96   Vaspal Salt and Chemicals (P) Ltd., No.:4/157,...              2
# 97   Velan Salt Private Limited, No.1/1, Avoodaiyar...              5
# 98   Velan Salt Private Limited, No.1/1, Avoodaiyar...             12
# 99   Vijayavelan Traders, 332, Sundaravelpuram, Tut...              1
# 100  Vinayaga Salt Traders, 4/379, Main Road, Mulla...              9
#
#      less_than_15  between_15_30  greater_than_30  Percentage_15_30
# 0               1              0                0          0.000000
# 1               6              0                0          0.000000
# 2               6              0                0          0.000000
# 3              13              3                0         18.750000
# 4               1              0                0          0.000000
# ..            ...            ...              ...               ...
# 96              0              1                1         50.000000
# 97              3              2                0         40.000000
# 98              0             12                0        100.000000
# 99              1              0                0          0.000000
# 100             6              3                0         33.333333
#
# [101 rows x 6 columns]

# %%
brand_performance = df.groupby('Brand')['Average ppm'].agg(
    less_than_15 = lambda x: (x < 15).sum(),
    between_15_30 = lambda x: ((x >= 15) & (x <= 30)).sum(),
    greater_than_30 = lambda x: (x > 30).sum()
).reset_index()

print("Brand wise performance:")
print(brand_performance)

brand_performance.to_excel('brand_performance.xlsx', index=False)
# Out:
# Brand wise performance:
#           Brand  less_than_15  between_15_30  greater_than_30
# 0            AK             6              0                0
# 1           AMS             2              0                0
# 2     AR Sakthi             1              1                0
# 3           ASR             6              0                0
# 4     Aanandham             0              4                0
# ..          ...           ...            ...              ...
# 129  White Dove             1              0                0
# 130  White Rose             1              0                0
# 131       i-Flo             0              2                0
# 132      i-Glow             3              1                0
# 133      i-rich             1              0                0
#
# [134 rows x 4 columns]

# %%
district_performance = df.groupby('District')['Average ppm'].agg(
    less_than_15 = lambda x: (x < 15).sum(),
    between_15_30 = lambda x: ((x >= 15) & (x <= 30)).sum(),
    greater_than_30 = lambda x: (x > 30).sum()
).reset_index()

print("District wise performance:")
print(district_performance)
district_performance.to_excel('district_performance.xlsx', index=False)
# Out:
# District wise performance:
#            District  less_than_15  between_15_30  greater_than_30
# 0          Ariyalur             1             13                6
# 1      Chengalpattu            11              5                4
# 2           Chennai            14              6                0
# 3        Coimbatore            14              6                0
# 4         Cuddalore             5             11                4
# 5        Dharmapuri            12              6                2
# 6          Dindugul             8              6                6
# 7             Erode            12              5                3
# 8      Kallakurichi             6              8                6
# 9       Kanchipuram             3             16                1
# 10    Kanniyakumari             2             18                0
# 11            Karur            12              2                6
# 12      Krishnagiri             8             12                0
# 13          Madurai             6             14                0
# 14     Nagapattinam             5             15                2
# 15         Namakkal             6              7                7
# 16       Perambalur             7             11                2
# 17       Pudukottai             3             13                4
# 18   Ramanadhapuram             6              8                6
# 19            Salem             6             14                0
# 20        Sivaganga             8              9                3
# 21          Tanjore            16              3                1
# 22          Tenkasi            19              1                0
# 23     The Nilgiris             4             15                1
# 24            Theni             7             11                2
# 25      Thiruvallur            10             10                0
# 26  Thiruvannamalai            11              8                1
# 27       Thiruvarur             4             14                2
# 28      Tirunelveli            14              4                2
# 29         Tiruppur            10             10                0
# 30           Trichy             2             12                6
# 31        Tuticorin            27             27                4
# 32          Vellore             7             13                0
# 33       Villupuram            10              3                7
# 34     Virudhunagar             4             12                4

# %%
salt_type_performance = df.groupby('Salt Type')['Average ppm'].agg(
    less_than_15=lambda x: (x < 15).sum(),
    between_15_30=lambda x: ((x >= 15) & (x <= 30)).sum(),
    greater_than_30=lambda x: (x > 30).sum()
).reset_index()

print("Salt type performance:")
print(salt_type_performance)
# Out:
# Salt type performance:
#   Salt Type  less_than_15  between_15_30  greater_than_30
# 0   Crystal           253            187               63
# 1    Powder            22             15                1
# 2    Refine            25            146               28

# %%
brand_district_performance = df.groupby(['District', 'Brand'])['Average ppm'].agg(
    less_than_15=lambda x: (x < 15).sum(),
    between_15_30=lambda x: ((x >= 15) & (x <= 30)).sum(),
    greater_than_30=lambda x: (x > 30).sum()
).reset_index()

# Function to find best, worst, and overperforming brands
def find_best_worst_overperforming(group):
    best_brand = group.loc[(group['between_15_30'] > 0)].sort_values(by='between_15_30', ascending=False).head(1)
    worst_brand = group.loc[(group['less_than_15'] > 0)].sort_values(by='less_than_15', ascending=False).head(1)
    overperforming_brand = group.loc[(group['greater_than_30'] > 0)].sort_values(by='greater_than_30', ascending=False).head(1)
    return pd.concat([best_brand, worst_brand, overperforming_brand])

# Apply the function to each district
best_worst_overperforming_brands = brand_district_performance.groupby('District').apply(find_best_worst_overperforming).reset_index(drop=True)

# Print the results
print("Best, Worst, and Overperforming Brands Across Each District:")
print(best_worst_overperforming_brands)

# Save to Excel
best_worst_overperforming_brands.to_excel('best_worst_overperforming_brands.xlsx', index=False)
# Out:
# Best, Worst, and Overperforming Brands Across Each District:
#         District       Brand  less_than_15  between_15_30  greater_than_30
# 0       Ariyalur     Kristal             0              6                1
# 1       Ariyalur    Saravana             1              1                0
# 2       Ariyalur     Piriyam             0              5                4
# 3   Chengalpattu  Aashirvaad             0              1                0
# 4   Chengalpattu        Tata             5              1                0
# ..           ...         ...           ...            ...              ...
# 90    Villupuram   Raja Gold             5              0                0
# 91    Villupuram        Tata             0              1                5
# 92  Virudhunagar        Tata             0              7                0
# 93  Virudhunagar       Arasu             2              0                0
# 94  Virudhunagar    Sprinkle             0              4                3
#
# [95 rows x 5 columns]

# %%
brand_district_performance = df.groupby(['District', 'Brand'])['Average ppm'].agg(
    less_than_15=lambda x: (x < 15).sum(),
    between_15_30=lambda x: ((x >= 15) & (x <= 30)).sum(),
    greater_than_30=lambda x: (x > 30).sum()
).reset_index()

# Function to find best, worst, and overperforming brands
def find_best_worst_overperforming(group):
    best_brand = group.loc[(group['between_15_30'] > 0)].sort_values(by='between_15_30', ascending=False).head(1)
    worst_brand = group.loc[(group['less_than_15'] > 0)].sort_values(by='less_than_15', ascending=False).head(1)
    overperforming_brand = group.loc[(group['greater_than_30'] > 0)].sort_values(by='greater_than_30', ascending=False).head(1)
    return best_brand, worst_brand, overperforming_brand

# Initialize lists to store results
districts = []
best_brands = []
worst_brands = []
overperforming_brands = []

# Apply the function to each district
for district, group in brand_district_performance.groupby('District'):
    best_brand, worst_brand, overperforming_brand = find_best_worst_overperforming(group)
    districts.append(district)
    best_brands.append(best_brand['Brand'].values[0] if not best_brand.empty else "N/A")
    worst_brands.append(worst_brand['Brand'].values[0] if not worst_brand.empty else "N/A")
    overperforming_brands.append(overperforming_brand['Brand'].values[0] if not overperforming_brand.empty else "N/A")

# Create the resulting DataFrame
result_df = pd.DataFrame({
    'District': districts,
    'Best Performing Brand': best_brands,
    'Worst Performing Brand': worst_brands,
    'Overperforming Brand': overperforming_brands
})

# Print the results
print("Best, Worst, and Overperforming Brands Across Each District:")
print(result_df)

# Save to Excel
result_df.to_excel('best_worst_overperforming_brands_summary.xlsx', index=False)
# Out:
# Best, Worst, and Overperforming Brands Across Each District:
#            District Best Performing Brand Worst Performing Brand  \
# 0          Ariyalur               Kristal               Saravana
# 1      Chengalpattu            Aashirvaad                   Tata
# 2           Chennai            Aashirvaad                   Baby
# 3        Coimbatore                  Mani                    SRM
# 4         Cuddalore               Kristal               Ayngaran
# 5        Dharmapuri               Kristal                     AK
# 6          Dindugul              Kasthuri               Kasthuri
# 7             Erode                  Tata                    ASR
# 8      Kallakurichi               Piriyam                Basanth
# 9       Kanchipuram                  Tata             Super Star
# 10    Kanniyakumari                  Tata               I-Shakti
# 11            Karur               Kristal                 Thambu
# 12      Krishnagiri           Annapoorani                     JJ
# 13          Madurai            Aashirvaad                    BVS
# 14     Nagapattinam               Kristal              Annapurna
# 15         Namakkal               Kristal                 Sakthi
# 16       Perambalur             Aanandham                Diamond
# 17       Pudukottai                  Real               Shanmuga
# 18   Ramanadhapuram               Kristal                   Tata
# 19            Salem           Sagar Shudh            Sagar Shudh
# 20        Sivaganga                  Anil                 Marina
# 21          Tanjore                 i-Flo   Sri Vetrivel Murugan
# 22          Tenkasi                 Sudha                  Sabar
# 23     The Nilgiris                 Surya                  Arasu
# 24            Theni              Mahilchi               Kasthuri
# 25      Thiruvallur                  Eata                  Annai
# 26  Thiruvannamalai              Ayngaran                  Apple
# 27       Thiruvarur               Kristal                    MSV
# 28      Tirunelveli                  Eata              Thirumani
# 29         Tiruppur               O Fresh             Hi Q Fresh
# 30           Trichy               Kristal                Kristee
# 31        Tuticorin               Kristal                   Tiru
# 32          Vellore              Sun Pure                     SK
# 33       Villupuram               Kristal              Raja Gold
# 34     Virudhunagar                  Tata                  Arasu
#
#    Overperforming Brand
# 0               Piriyam
# 1              Udhaiyam
# 2                   N/A
# 3                   N/A
# 4               Kristal
# 5               O Fresh
# 6                   NCS
# 7                  Tata
# 8               Piriyam
# 9               Piriyam
# 10                  N/A
# 11              Kristal
# 12                  N/A
# 13                  N/A
# 14           Aashirvaad
# 15               Seasun
# 16                Jeyel
# 17              Kristal
# 18              Piriyam
# 19                  N/A
# 20              Adithya
# 21              Diamond
# 22                  N/A
# 23                Arasu
# 24             Kasthuri
# 25                  N/A
# 26              Kristal
# 27             Saravana
# 28            Annapurna
# 29                  N/A
# 30              Kristee
# 31                  CKC
# 32                  N/A
# 33                 Tata
# 34             Sprinkle

# %%
aggregated_data = df.groupby(['District', 'Producer']).agg(
    total_samples=('Average ppm', 'count'),
    samples_below_15=('Average ppm', lambda x: (x < 15).sum()),
    samples_15_to_30=('Average ppm', lambda x: ((x >= 15) & (x <= 30)).sum()),
    samples_above_30=('Average ppm', lambda x: (x > 30).sum())
).reset_index()

# Determine top 10 producers based on different criteria
top_best_producers = aggregated_data.sort_values(by='samples_15_to_30', ascending=False).head(10)
top_worst_producers = aggregated_data.sort_values(by='samples_below_15', ascending=False).head(10)
top_overperforming_producers = aggregated_data.sort_values(by='samples_above_30', ascending=False).head(10)

# Save results to an Excel file
with pd.ExcelWriter('top_producers_analysis.xlsx') as writer:
    top_best_producers.to_excel(writer, sheet_name='Top 10 Best Producers', index=False)
    top_worst_producers.to_excel(writer, sheet_name='Top 10 Worst Producers', index=False)
    top_overperforming_producers.to_excel(writer, sheet_name='Top 10 Overperforming Producers', index=False)

# Display the top producers for each category
print("Top 10 Best Producers (15-30 ppm):")
print(top_best_producers)
print("\nTop 10 Worst Producers (<15 ppm):")
print(top_worst_producers)
print("\nTop 10 Overperforming Producers (>30 ppm):")
print(top_overperforming_producers)
# Out:
# Top 10 Best Producers (15-30 ppm):
#           District                                           Producer  \
# 180   The Nilgiris  Basuvi Salt Company, 30/4, Nandagopalapuram We...
# 121   Nagapattinam  VKS Foods Pvt. Ltd. 2/65-1, 2/65-2, ECR Road, ...
# 41       Cuddalore  Escee Industries Private Limited, 2/234, Melma...
# 187          Theni  Ganesh Powder Salt Company, 193/41, Old Market...
# 86   Kanniyakumari  Raj Salt Industries, C63, Sipcot Industrial Co...
# 85   Kanniyakumari  Maheshwari Salt Trading Co. Door No. 3/29, Plo...
# 0         Ariyalur  Escee Industries Private Limited, 2/234, Melma...
# 282        Vellore  Swamy Traders & Enterprises Pvt. Ltd, 653/1, T...
# 230         Trichy  Escee Industries Private Limited, 2/234, Melma...
# 203     Thiruvarur  Escee Industries Private Limited, 2/234, Melma...
#
#      total_samples  samples_below_15  samples_15_to_30  samples_above_30
# 180             14                 1                13                 0
# 121              9                 0                 9                 0
# 41               9                 0                 7                 2
# 187             14                 6                 7                 1
# 86               9                 2                 7                 0
# 85               7                 0                 7                 0
# 0                7                 0                 6                 1
# 282              6                 0                 6                 0
# 230              6                 0                 6                 0
# 203              6                 0                 6                 0
#
# Top 10 Worst Producers (<15 ppm):
#             District                                           Producer  \
# 217      Tirunelveli  Tirumani salt , 102, Sankarapuram, Tuticorin-6...
# 171          Tanjore  Sri Vetrivel Murugan Salt, 2/17, Sarpoji Marke...
# 129       Perambalur  Jayalakshmi & Co, 225/1, Ayyanarpuram post, Ke...
# 287       Villupuram  P.Karthickraja, 107/1-A, 1st Street, Krishnara...
# 195      Thiruvallur  NMS Exports, 109/3A, Polepettat, Ettayapuram R...
# 187            Theni  Ganesh Powder Salt Company, 193/41, Old Market...
# 167          Tanjore  R.Thambu Sivasubramanian, 64-A, 3 Andal Street...
# 199  Thiruvannamalai  Shivayah Salt Private Limited, 5/311-2, Palaya...
# 96       Krishnagiri  Akash, 5B/478, SNR Nagar, Chidambara Nagar, Th...
# 258        Tuticorin  R.Ashok Raj Inc, Salt Exporters & Traders, 17/...
#
#      total_samples  samples_below_15  samples_15_to_30  samples_above_30
# 217             14                14                 0                 0
# 171              9                 9                 0                 0
# 129             12                 7                 3                 2
# 287              6                 6                 0                 0
# 195              8                 6                 2                 0
# 187             14                 6                 7                 1
# 167              6                 6                 0                 0
# 199              6                 5                 1                 0
# 96               5                 5                 0                 0
# 258              5                 5                 0                 0
#
# Top 10 Overperforming Producers (>30 ppm):
#            District                                           Producer  \
# 126        Namakkal  T.K.Rajendran and Sons, 84/3, South Raja Stree...
# 55         Dindugul  Ganesh Powder Salt Company, 193/41, Old Market...
# 89            Karur  Escee Industries Private Limited, 2/234, Melma...
# 286      Villupuram  Maheshwari Salt Trading Co. Door No. 3/29, Plo...
# 234          Trichy  Swamy Traders & Enterprises Pvt. Ltd, 653/1, T...
# 73     Kallakurichi  Swamy Traders & Enterprises Pvt. Ltd, 653/1, T...
# 3          Ariyalur  Swamy Traders & Enterprises Pvt. Ltd, 653/1, T...
# 141  Ramanadhapuram  Escee Industries Private Limited, 2/234, Melma...
# 297    Virudhunagar  Sahayamatha Salterns P Ltd, At Survey No.1&2/3...
# 63            Erode  Maheshwari Salt Trading Co. Door No. 3/29, Plo...
#
#      total_samples  samples_below_15  samples_15_to_30  samples_above_30
# 126              7                 0                 1                 6
# 55              16                 4                 6                 6
# 89               6                 0                 1                 5
# 286              5                 0                 0                 5
# 234              7                 1                 1                 5
# 73               6                 1                 0                 5
# 3                9                 0                 5                 4
# 141              7                 0                 3                 4
# 297              7                 0                 4                 3
# 63               6                 0                 3                 3
